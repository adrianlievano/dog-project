# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
human_faces_list = []
dog_faces_list = []

human_counter_t = 0
dog_counter_t = 0
human_counter_f = 0
dog_counter_f = 0

#Tests performance of human_files on face detection algorithm
for i in range(100):
    human_faces_list.append(face_detector(human_files_short[i]))    
    if (human_faces_list[i]==True):
        human_counter_t+=1
    elif (human_faces_list[i]==False):
        human_counter_f+=1

for i in range(100):
    dog_faces_list.append(face_detector(dog_files_short[i]))    
    if (dog_faces_list[i]==True):
        dog_counter_t+=1
    elif (dog_faces_list[i]==False):
        dog_counter_f+=1      

print("{}% of the first 100 images in human_files have detected a human face".format(human_counter_t/(len(human_files_short))*100))
print("{}% of the first 100 images in dog_files have detected a human face".format(dog_counter_t/(len(dog_files_short))*100))

#1. 98% of the first 100 images of the human_files_short are accurately predicting a human face. 
#2. 11% of human faces are detected in the dog_files_short file using the face_detector algorithm
# Out:
# 98.0% of the first 100 images in human_files have detected a human face
# 11.0% of the first 100 images in dog_files have detected a human face

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
#Question 2: 
#Not a reasonable request. 
#Users would be upset and frustrated and eventually another competitor with more dedication will win them over. 

## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.
import cv2 
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')
eye_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_eye.xml')
smile_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_smile.xml')


#Couldn't find the .xml files =( #
#left_ear_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_mcs_leftear_alt.xml')
#right_ear_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_mcs_rightear_alt.xml')

# returns "True" if face is detected in image stored at img_path
human_files_short = human_files[:100]
dog_files_short = train_files[:100]

def face_detector_2(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    eyes = eye_cascade.detectMultiScale(gray)
    smile = smile_cascade.detectMultiScale(gray)
    
    if (len(faces)+len(eyes)+len(smile) > 1) :
        return True, len(faces)+len(eyes)+len(smile)
    

## TODO: Test the performance of the face_detector algorithm 
human_faces_list = []
dog_faces_list = []
human_counter_t = 0
dog_counter_t = 0
human_counter_f = 0
dog_counter_f = 0

face_detector_2(human_files_short[1])


faces = face_cascade.detectMultiScale(gray)
eyes = eye_cascade.detectMultiScale(gray)
smile = smile_cascade.detectMultiScale(gray)

img = cv2.imread(human_files_short[2])
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

for (x,y,w,h) in faces:
    # add bounding box to color image
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    for (sx,sy,sw,sh) in smile:
        cv2.rectangle(roi_color,(sx,sy),(sx+sw,sy+sh),(255,255,0),2)
 
    
# display the image, along with bounding box
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(cv_rgb)
plt.show()
print('Number of faces detected:', len(faces))
print('Number of eyes detected:', len(eyes))
print('Number of smiles detected:', len(smile))

# find faces in image
img2 = cv2.imread(dog_files_short[1])
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
faces2 = face_cascade.detectMultiScale(gray)


# print number of faces detected in the image


# get bounding box for each detected face
for (x,y,w,h) in faces2:
    # add bounding box to color image
    cv2.rectangle(img2,(x,y),(x+w,y+h),(255,0,255),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
print('Number of faces detected:', len(faces2))
# Out:
# Number of faces detected: 1
# Number of eyes detected: 2
# Number of smiles detected: 6
# Number of faces detected: 1

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
human_faces_list = []
dog_faces_list = []

human_counter_t = 0
dog_counter_t = 0
human_counter_f = 0
dog_counter_f = 0

#Tests performance of human_files on face detection algorithm
for i in range(len(human_files_short)):
    human_faces_list.append(dog_detector(human_files_short[i]))    
    if (human_faces_list[i]==True):
        human_counter_t+=1
    elif (human_faces_list[i]==False):
        human_counter_f+=1

for i in range(len(dog_files_short)):
    dog_faces_list.append(dog_detector(dog_files_short[i]))    
    if (dog_faces_list[i]==True):
        dog_counter_t+=1
    elif (dog_faces_list[i]==False):
        dog_counter_f+=1      

print("{}% of the first 100 images in human_files have detected a dog using ResNet Dog Detector".format(human_counter_t/(len(human_files_short))*100))
print("{}% of the first 100 images in dog_files have detected a dog using ResNet Dog Detector".format(dog_counter_t/(len(dog_files_short))*100))

#1. 98% of the first 100 images of the human_files_short are accurately predicting a human face. 
#2. 11% of human faces are detected in the dog_files_short file using the face_detector algorithm
# Out:
# 2.0% of the first 100 images in human_files have detected a dog using ResNet Dog Detector
# 100.0% of the first 100 images in dog_files have detected a dog using ResNet Dog Detector

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:52<00:00, 126.05it/s]
# 100%|██████████| 835/835 [00:05<00:00, 140.95it/s]
# 100%|██████████| 836/836 [00:05<00:00, 141.78it/s]

# %%
train_tensors.shape
# Out:
# (6680, 224, 224, 3)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()


### TODO: Define your architecture.
model.add(Conv2D(16, (2,2), strides=(1,1), padding='same', input_shape=train_tensors.shape[1:], activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
model.add(Conv2D(32,(4,4), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
model.add(Conv2D(64,(2,2), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
#model.add(GlobalAveragePooling2D())
model.add(Flatten())
model.add(Dense(133,activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 50176)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               6673541
# =================================================================
# Total params: 6,690,229.0
# Trainable params: 6,690,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 5

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.8121 - acc: 0.0233Epoch 00000: val_loss improved from inf to 4.58492, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 28s - loss: 4.8127 - acc: 0.0232 - val_loss: 4.5849 - val_acc: 0.0491
# Epoch 2/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 4.0068 - acc: 0.1414Epoch 00001: val_loss improved from 4.58492 to 4.44787, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 27s - loss: 4.0072 - acc: 0.1412 - val_loss: 4.4479 - val_acc: 0.0743
# Epoch 3/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4283 - acc: 0.4401Epoch 00002: val_loss did not improve
# 6680/6680 [==============================] - 27s - loss: 2.4291 - acc: 0.4400 - val_loss: 6.0433 - val_acc: 0.0826
# Epoch 4/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.0591 - acc: 0.7351Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 27s - loss: 1.0596 - acc: 0.7350 - val_loss: 6.5322 - val_acc: 0.0707
# Epoch 5/5
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.3615 - acc: 0.9044Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 27s - loss: 0.3610 - acc: 0.9045 - val_loss: 7.5935 - val_acc: 0.0790

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 7.8947%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229.0
# Trainable params: 68,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 12.3163 - acc: 0.1207Epoch 00000: val_loss improved from inf to 10.75496, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 12.2996 - acc: 0.1216 - val_loss: 10.7550 - val_acc: 0.2048
# Epoch 2/20
# 6560/6680 [============================>.] - ETA: 0s - loss: 10.0535 - acc: 0.2912Epoch 00001: val_loss improved from 10.75496 to 10.10491, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 10.0535 - acc: 0.2919 - val_loss: 10.1049 - val_acc: 0.2754
# Epoch 3/20
# 6540/6680 [============================>.] - ETA: 0s - loss: 9.6391 - acc: 0.3450Epoch 00002: val_loss improved from 10.10491 to 9.79225, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.6223 - acc: 0.3467 - val_loss: 9.7922 - val_acc: 0.3162
# Epoch 4/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.3360 - acc: 0.3781Epoch 00003: val_loss improved from 9.79225 to 9.59407, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.3333 - acc: 0.3781 - val_loss: 9.5941 - val_acc: 0.3293
# Epoch 5/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 9.1090 - acc: 0.3979Epoch 00004: val_loss improved from 9.59407 to 9.49041, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 9.1055 - acc: 0.3984 - val_loss: 9.4904 - val_acc: 0.3449
# Epoch 6/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.9677 - acc: 0.4142Epoch 00005: val_loss improved from 9.49041 to 9.40288, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.9768 - acc: 0.4138 - val_loss: 9.4029 - val_acc: 0.3521
# Epoch 7/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 8.9047 - acc: 0.4286Epoch 00006: val_loss improved from 9.40288 to 9.39435, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.9310 - acc: 0.4269 - val_loss: 9.3943 - val_acc: 0.3485
# Epoch 8/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 8.8836 - acc: 0.4332Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 8.8893 - acc: 0.4326 - val_loss: 9.4104 - val_acc: 0.3449
# Epoch 9/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 8.7847 - acc: 0.4372Epoch 00008: val_loss improved from 9.39435 to 9.15752, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.7867 - acc: 0.4371 - val_loss: 9.1575 - val_acc: 0.3581
# Epoch 10/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.5168 - acc: 0.4469Epoch 00009: val_loss improved from 9.15752 to 9.02050, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.4879 - acc: 0.4488 - val_loss: 9.0205 - val_acc: 0.3772
# Epoch 11/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.2645 - acc: 0.4668Epoch 00010: val_loss improved from 9.02050 to 8.73760, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.2703 - acc: 0.4663 - val_loss: 8.7376 - val_acc: 0.3916
# Epoch 12/20
# 6440/6680 [===========================>..] - ETA: 0s - loss: 8.1854 - acc: 0.4738Epoch 00011: val_loss improved from 8.73760 to 8.63553, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.1453 - acc: 0.4756 - val_loss: 8.6355 - val_acc: 0.3880
# Epoch 13/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.8449 - acc: 0.4914Epoch 00012: val_loss improved from 8.63553 to 8.33642, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.8583 - acc: 0.4907 - val_loss: 8.3364 - val_acc: 0.4108
# Epoch 14/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 7.7655 - acc: 0.5022Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.7590 - acc: 0.5024 - val_loss: 8.3825 - val_acc: 0.4096
# Epoch 15/20
# 6420/6680 [===========================>..] - ETA: 0s - loss: 7.6484 - acc: 0.5117Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.6741 - acc: 0.5103 - val_loss: 8.3521 - val_acc: 0.4156
# Epoch 16/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 7.6037 - acc: 0.5165Epoch 00015: val_loss improved from 8.33642 to 8.26882, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.6147 - acc: 0.5157 - val_loss: 8.2688 - val_acc: 0.4192
# Epoch 17/20
# 6600/6680 [============================>.] - ETA: 0s - loss: 7.5605 - acc: 0.5189Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 1s - loss: 7.5637 - acc: 0.5183 - val_loss: 8.2817 - val_acc: 0.4132
# Epoch 18/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.4542 - acc: 0.5255Epoch 00017: val_loss improved from 8.26882 to 8.18681, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.4562 - acc: 0.5253 - val_loss: 8.1868 - val_acc: 0.4228
# Epoch 19/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 7.4224 - acc: 0.5339Epoch 00018: val_loss improved from 8.18681 to 8.10149, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.4118 - acc: 0.5346 - val_loss: 8.1015 - val_acc: 0.4323
# Epoch 20/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 7.3873 - acc: 0.5339Epoch 00019: val_loss improved from 8.10149 to 8.07311, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 7.3845 - acc: 0.5341 - val_loss: 8.0731 - val_acc: 0.4395

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 43.7799%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

bottleneck_features=np.load('bottleneck_features/DogResnet50Data.npz')
#np.load('bottleneck_features/DogVGG16Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.

Resnet50_model=Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='softmax'))
Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_6 ( (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517.0
# Trainable params: 272,517.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Resnet50_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=200, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6109 - acc: 0.6017Epoch 00000: val_loss improved from inf to 0.82328, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 12s - loss: 1.6079 - acc: 0.6022 - val_loss: 0.8233 - val_acc: 0.7557
# Epoch 2/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.4363 - acc: 0.8640Epoch 00001: val_loss improved from 0.82328 to 0.72969, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s - loss: 0.4361 - acc: 0.8645 - val_loss: 0.7297 - val_acc: 0.7737
# Epoch 3/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.2623 - acc: 0.9125Epoch 00002: val_loss improved from 0.72969 to 0.62502, saving model to saved_models/weights.best.Resnet50.hdf5
# 6680/6680 [==============================] - 2s - loss: 0.2616 - acc: 0.9129 - val_loss: 0.6250 - val_acc: 0.8072
# Epoch 4/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.1764 - acc: 0.9452Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.1761 - acc: 0.9454 - val_loss: 0.6927 - val_acc: 0.8024
# Epoch 5/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.1236 - acc: 0.9612Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.1229 - acc: 0.9611 - val_loss: 0.7054 - val_acc: 0.8108
# Epoch 6/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0881 - acc: 0.9724Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0887 - acc: 0.9722 - val_loss: 0.6470 - val_acc: 0.8228
# Epoch 7/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0643 - acc: 0.9809Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0642 - acc: 0.9808 - val_loss: 0.7004 - val_acc: 0.8180
# Epoch 8/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0481 - acc: 0.9862Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0479 - acc: 0.9861 - val_loss: 0.7094 - val_acc: 0.8180
# Epoch 9/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0388 - acc: 0.9887Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0387 - acc: 0.9888 - val_loss: 0.7089 - val_acc: 0.8156
# Epoch 10/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0274 - acc: 0.9916Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0273 - acc: 0.9916 - val_loss: 0.6942 - val_acc: 0.8240
# Epoch 11/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0220 - acc: 0.9947Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0219 - acc: 0.9948 - val_loss: 0.8323 - val_acc: 0.8060
# Epoch 12/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0178 - acc: 0.9955Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0177 - acc: 0.9955 - val_loss: 0.7556 - val_acc: 0.8359
# Epoch 13/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0135 - acc: 0.9969Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0134 - acc: 0.9969 - val_loss: 0.7844 - val_acc: 0.8359
# Epoch 14/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0112 - acc: 0.9971Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0111 - acc: 0.9972 - val_loss: 0.7952 - val_acc: 0.8275
# Epoch 15/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0100 - acc: 0.9974Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0100 - acc: 0.9975 - val_loss: 0.8395 - val_acc: 0.8359
# Epoch 16/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0090 - acc: 0.9978Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0088 - acc: 0.9979 - val_loss: 0.8922 - val_acc: 0.8204
# Epoch 17/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0065 - acc: 0.9983Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0080 - acc: 0.9981 - val_loss: 0.9032 - val_acc: 0.8251
# Epoch 18/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0083 - acc: 0.9976Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0082 - acc: 0.9976 - val_loss: 0.9107 - val_acc: 0.8323
# Epoch 19/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9985Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0058 - acc: 0.9984 - val_loss: 0.8848 - val_acc: 0.8251
# Epoch 20/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0070 - acc: 0.9988Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0070 - acc: 0.9988 - val_loss: 0.9214 - val_acc: 0.8299
# Epoch 21/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9989Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9990 - val_loss: 0.9308 - val_acc: 0.8287
# Epoch 22/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 0.9458 - val_acc: 0.8216
# Epoch 23/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0055 - acc: 0.9986Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9987 - val_loss: 1.0053 - val_acc: 0.8120
# Epoch 24/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9988Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9988 - val_loss: 0.9766 - val_acc: 0.8275
# Epoch 25/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9988Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9988 - val_loss: 1.0073 - val_acc: 0.8275
# Epoch 26/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9986Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9987 - val_loss: 1.0303 - val_acc: 0.8419
# Epoch 27/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9988Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0056 - acc: 0.9988 - val_loss: 1.0593 - val_acc: 0.8323
# Epoch 28/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9985Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9985 - val_loss: 1.0655 - val_acc: 0.8180
# Epoch 29/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.9985Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9985 - val_loss: 1.0573 - val_acc: 0.8287
# Epoch 30/200
# 6540/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9988Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9987 - val_loss: 1.0874 - val_acc: 0.8275
# Epoch 31/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9989Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9990 - val_loss: 1.1031 - val_acc: 0.8335
# Epoch 32/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9985Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9985 - val_loss: 1.1164 - val_acc: 0.8263
# Epoch 33/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9989Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9990 - val_loss: 1.0942 - val_acc: 0.8407
# Epoch 34/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.9994Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9991 - val_loss: 1.1611 - val_acc: 0.8216
# Epoch 35/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0055 - acc: 0.9991Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9991 - val_loss: 1.1924 - val_acc: 0.8228
# Epoch 36/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9991Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0056 - acc: 0.9990 - val_loss: 1.1548 - val_acc: 0.8144
# Epoch 37/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9986Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0036 - acc: 0.9987 - val_loss: 1.1476 - val_acc: 0.8251
# Epoch 38/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0066 - acc: 0.9989Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0065 - acc: 0.9990 - val_loss: 1.1584 - val_acc: 0.8263
# Epoch 39/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0060 - acc: 0.9991Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0060 - acc: 0.9991 - val_loss: 1.1575 - val_acc: 0.8240
# Epoch 40/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9988 - val_loss: 1.1693 - val_acc: 0.8240
# Epoch 41/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9988Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0055 - acc: 0.9988 - val_loss: 1.1625 - val_acc: 0.8216
# Epoch 42/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.1690 - val_acc: 0.8299
# Epoch 43/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9988Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.1713 - val_acc: 0.8359
# Epoch 44/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.1971 - val_acc: 0.8299
# Epoch 45/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9985Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0030 - acc: 0.9985 - val_loss: 1.2074 - val_acc: 0.8311
# Epoch 46/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9989Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9988 - val_loss: 1.1999 - val_acc: 0.8323
# Epoch 47/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9988 - val_loss: 1.2395 - val_acc: 0.8251
# Epoch 48/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0034 - acc: 0.9991Epoch 00047: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9988 - val_loss: 1.2322 - val_acc: 0.8228
# Epoch 49/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2257 - val_acc: 0.8263
# Epoch 50/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.2164 - val_acc: 0.8275
# Epoch 51/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9986Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9987 - val_loss: 1.2320 - val_acc: 0.8251
# Epoch 52/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9985Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9985 - val_loss: 1.2148 - val_acc: 0.8263
# Epoch 53/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9991Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9991 - val_loss: 1.2474 - val_acc: 0.8240
# Epoch 54/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9988Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9988 - val_loss: 1.2340 - val_acc: 0.8240
# Epoch 55/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9986Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9985 - val_loss: 1.2341 - val_acc: 0.8299
# Epoch 56/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.9985Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9985 - val_loss: 1.2262 - val_acc: 0.8263
# Epoch 57/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9985Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9985 - val_loss: 1.2686 - val_acc: 0.8228
# Epoch 58/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9985Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9985 - val_loss: 1.2438 - val_acc: 0.8228
# Epoch 59/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9989Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9988 - val_loss: 1.2472 - val_acc: 0.8228
# Epoch 60/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9991Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9990 - val_loss: 1.2448 - val_acc: 0.8228
# Epoch 61/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0063 - acc: 0.9989Epoch 00060: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0063 - acc: 0.9990 - val_loss: 1.2465 - val_acc: 0.8251
# Epoch 62/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00061: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9990 - val_loss: 1.2632 - val_acc: 0.8263
# Epoch 63/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.9985Epoch 00062: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9985 - val_loss: 1.2751 - val_acc: 0.8263
# Epoch 64/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9988Epoch 00063: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0037 - acc: 0.9988 - val_loss: 1.2875 - val_acc: 0.8323
# Epoch 65/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00064: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.2913 - val_acc: 0.8263
# Epoch 66/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.9988Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0035 - acc: 0.9988 - val_loss: 1.2802 - val_acc: 0.8263
# Epoch 67/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.2610 - val_acc: 0.8263
# Epoch 68/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0055 - acc: 0.9988Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0053 - acc: 0.9988 - val_loss: 1.2531 - val_acc: 0.8240
# Epoch 69/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9985Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9985 - val_loss: 1.2546 - val_acc: 0.8263
# Epoch 70/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9988Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.2577 - val_acc: 0.8251
# Epoch 71/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9987 - val_loss: 1.2721 - val_acc: 0.8263
# Epoch 72/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9991Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9991 - val_loss: 1.2637 - val_acc: 0.8263
# Epoch 73/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0032 - acc: 0.9988Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9987 - val_loss: 1.2540 - val_acc: 0.8240
# Epoch 74/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9988Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9988 - val_loss: 1.2632 - val_acc: 0.8251
# Epoch 75/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9983Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0038 - acc: 0.9984 - val_loss: 1.2885 - val_acc: 0.8299
# Epoch 76/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9989Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9990 - val_loss: 1.2515 - val_acc: 0.8263
# Epoch 77/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9989Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.2569 - val_acc: 0.8263
# Epoch 78/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9988Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9987 - val_loss: 1.2622 - val_acc: 0.8263
# Epoch 79/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9990 - val_loss: 1.2709 - val_acc: 0.8228
# Epoch 80/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9991Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0056 - acc: 0.9990 - val_loss: 1.2635 - val_acc: 0.8240
# Epoch 81/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.2781 - val_acc: 0.8275
# Epoch 82/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9986Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9987 - val_loss: 1.2543 - val_acc: 0.8263
# Epoch 83/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9988Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0037 - acc: 0.9988 - val_loss: 1.2679 - val_acc: 0.8228
# Epoch 84/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.9989Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9990 - val_loss: 1.2859 - val_acc: 0.8251
# Epoch 85/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.2599 - val_acc: 0.8228
# Epoch 86/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9988Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9988 - val_loss: 1.2834 - val_acc: 0.8228
# Epoch 87/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9988Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9988 - val_loss: 1.2904 - val_acc: 0.8299
# Epoch 88/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9989Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9990 - val_loss: 1.2772 - val_acc: 0.8287
# Epoch 89/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0055 - acc: 0.9988Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9988 - val_loss: 1.2685 - val_acc: 0.8287
# Epoch 90/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9989Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.2730 - val_acc: 0.8251
# Epoch 91/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9988Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9988 - val_loss: 1.2735 - val_acc: 0.8251
# Epoch 92/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0056 - acc: 0.9989Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0055 - acc: 0.9990 - val_loss: 1.2643 - val_acc: 0.8263
# Epoch 93/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9988Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.2787 - val_acc: 0.8228
# Epoch 94/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9988Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9988 - val_loss: 1.2789 - val_acc: 0.8287
# Epoch 95/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2903 - val_acc: 0.8275
# Epoch 96/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2977 - val_acc: 0.8263
# Epoch 97/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2905 - val_acc: 0.8275
# Epoch 98/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9986Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.2785 - val_acc: 0.8240
# Epoch 99/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9986Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9987 - val_loss: 1.3019 - val_acc: 0.8263
# Epoch 100/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9986Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9987 - val_loss: 1.2969 - val_acc: 0.8275
# Epoch 101/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00100: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9988 - val_loss: 1.2839 - val_acc: 0.8240
# Epoch 102/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9988Epoch 00101: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.2659 - val_acc: 0.8299
# Epoch 103/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9986Epoch 00102: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9987 - val_loss: 1.2696 - val_acc: 0.8240
# Epoch 104/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9986Epoch 00103: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9985 - val_loss: 1.2896 - val_acc: 0.8240
# Epoch 105/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00104: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9988 - val_loss: 1.2918 - val_acc: 0.8240
# Epoch 106/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.9988Epoch 00105: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9987 - val_loss: 1.2912 - val_acc: 0.8228
# Epoch 107/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9986Epoch 00106: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9987 - val_loss: 1.2893 - val_acc: 0.8287
# Epoch 108/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00107: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9987 - val_loss: 1.2922 - val_acc: 0.8240
# Epoch 109/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9989Epoch 00108: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9990 - val_loss: 1.3056 - val_acc: 0.8287
# Epoch 110/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9986Epoch 00109: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0053 - acc: 0.9987 - val_loss: 1.2893 - val_acc: 0.8263
# Epoch 111/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9989Epoch 00110: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9990 - val_loss: 1.2684 - val_acc: 0.8263
# Epoch 112/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9986Epoch 00111: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9987 - val_loss: 1.2910 - val_acc: 0.8275
# Epoch 113/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9985Epoch 00112: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9985 - val_loss: 1.2840 - val_acc: 0.8287
# Epoch 114/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9986Epoch 00113: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9987 - val_loss: 1.2829 - val_acc: 0.8263
# Epoch 115/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.9989Epoch 00114: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.2744 - val_acc: 0.8263
# Epoch 116/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00115: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9987 - val_loss: 1.2745 - val_acc: 0.8275
# Epoch 117/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9985Epoch 00116: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9985 - val_loss: 1.2668 - val_acc: 0.8323
# Epoch 118/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9989Epoch 00117: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9988 - val_loss: 1.2704 - val_acc: 0.8311
# Epoch 119/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00118: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2875 - val_acc: 0.8251
# Epoch 120/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00119: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9987 - val_loss: 1.2836 - val_acc: 0.8240
# Epoch 121/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9989Epoch 00120: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9990 - val_loss: 1.2908 - val_acc: 0.8275
# Epoch 122/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00121: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9987 - val_loss: 1.2899 - val_acc: 0.8251
# Epoch 123/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0030 - acc: 0.9989Epoch 00122: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9988 - val_loss: 1.2767 - val_acc: 0.8192
# Epoch 124/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9989Epoch 00123: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9990 - val_loss: 1.2875 - val_acc: 0.8287
# Epoch 125/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9986Epoch 00124: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9987 - val_loss: 1.3021 - val_acc: 0.8263
# Epoch 126/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9988Epoch 00125: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.3001 - val_acc: 0.8228
# Epoch 127/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00126: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9988 - val_loss: 1.2864 - val_acc: 0.8228
# Epoch 128/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9986Epoch 00127: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.2848 - val_acc: 0.8216
# Epoch 129/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0036 - acc: 0.9989Epoch 00128: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9988 - val_loss: 1.2932 - val_acc: 0.8204
# Epoch 130/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9989Epoch 00129: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9990 - val_loss: 1.2809 - val_acc: 0.8251
# Epoch 131/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9985Epoch 00130: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9985 - val_loss: 1.2853 - val_acc: 0.8299
# Epoch 132/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9991Epoch 00131: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9991 - val_loss: 1.2897 - val_acc: 0.8287
# Epoch 133/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.9986Epoch 00132: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9987 - val_loss: 1.3069 - val_acc: 0.8240
# Epoch 134/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9989Epoch 00133: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9990 - val_loss: 1.2853 - val_acc: 0.8299
# Epoch 135/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9986Epoch 00134: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.2874 - val_acc: 0.8251
# Epoch 136/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00135: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9990 - val_loss: 1.3014 - val_acc: 0.8263
# Epoch 137/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9985Epoch 00136: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9985 - val_loss: 1.3023 - val_acc: 0.8240
# Epoch 138/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9985Epoch 00137: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9985 - val_loss: 1.3046 - val_acc: 0.8228
# Epoch 139/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9988Epoch 00138: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9988 - val_loss: 1.3102 - val_acc: 0.8204
# Epoch 140/200
# 6600/6680 [============================>.] - ETA: 0s - loss: 0.0054 - acc: 0.9989Epoch 00139: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0054 - acc: 0.9990 - val_loss: 1.2988 - val_acc: 0.8228
# Epoch 141/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0053 - acc: 0.9988Epoch 00140: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.2947 - val_acc: 0.8240
# Epoch 142/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00141: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.2949 - val_acc: 0.8240
# Epoch 143/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9989Epoch 00142: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.2956 - val_acc: 0.8180
# Epoch 144/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9988Epoch 00143: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.2945 - val_acc: 0.8228
# Epoch 145/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00144: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.2953 - val_acc: 0.8251
# Epoch 146/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9986Epoch 00145: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9987 - val_loss: 1.3102 - val_acc: 0.8251
# Epoch 147/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9989Epoch 00146: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9990 - val_loss: 1.3100 - val_acc: 0.8240
# Epoch 148/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9991Epoch 00147: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9991 - val_loss: 1.2909 - val_acc: 0.8263
# Epoch 149/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9989Epoch 00148: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9990 - val_loss: 1.2954 - val_acc: 0.8240
# Epoch 150/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9985Epoch 00149: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9985 - val_loss: 1.2964 - val_acc: 0.8263
# Epoch 151/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9985Epoch 00150: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9985 - val_loss: 1.3010 - val_acc: 0.8228
# Epoch 152/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00151: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.3024 - val_acc: 0.8240
# Epoch 153/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9988Epoch 00152: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9988 - val_loss: 1.3081 - val_acc: 0.8251
# Epoch 154/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.9989Epoch 00153: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9990 - val_loss: 1.3281 - val_acc: 0.8275
# Epoch 155/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9989Epoch 00154: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.3111 - val_acc: 0.8228
# Epoch 156/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9986Epoch 00155: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9987 - val_loss: 1.3053 - val_acc: 0.8168
# Epoch 157/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9988Epoch 00156: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.3001 - val_acc: 0.8168
# Epoch 158/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00157: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9988 - val_loss: 1.3053 - val_acc: 0.8192
# Epoch 159/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00158: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.3030 - val_acc: 0.8228
# Epoch 160/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9989Epoch 00159: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9990 - val_loss: 1.3099 - val_acc: 0.8204
# Epoch 161/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9988Epoch 00160: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.3028 - val_acc: 0.8240
# Epoch 162/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9985Epoch 00161: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9985 - val_loss: 1.3058 - val_acc: 0.8204
# Epoch 163/200
# 6580/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00162: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.3028 - val_acc: 0.8216
# Epoch 164/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9989Epoch 00163: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.3074 - val_acc: 0.8275
# Epoch 165/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9988Epoch 00164: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.2901 - val_acc: 0.8251
# Epoch 166/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00165: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9988 - val_loss: 1.2948 - val_acc: 0.8240
# Epoch 167/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9991Epoch 00166: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9991 - val_loss: 1.3172 - val_acc: 0.8251
# Epoch 168/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.9991Epoch 00167: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9990 - val_loss: 1.3098 - val_acc: 0.8275
# Epoch 169/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9988Epoch 00168: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9988 - val_loss: 1.3003 - val_acc: 0.8228
# Epoch 170/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9985Epoch 00169: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9985 - val_loss: 1.3142 - val_acc: 0.8263
# Epoch 171/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00170: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.3160 - val_acc: 0.8228
# Epoch 172/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0052 - acc: 0.9988Epoch 00171: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9988 - val_loss: 1.3184 - val_acc: 0.8228
# Epoch 173/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9986Epoch 00172: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9987 - val_loss: 1.3164 - val_acc: 0.8180
# Epoch 174/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9991Epoch 00173: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9991 - val_loss: 1.3117 - val_acc: 0.8228
# Epoch 175/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9991Epoch 00174: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0046 - acc: 0.9991 - val_loss: 1.3085 - val_acc: 0.8204
# Epoch 176/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0033 - acc: 0.9991Epoch 00175: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0039 - acc: 0.9990 - val_loss: 1.3095 - val_acc: 0.8251
# Epoch 177/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.9991Epoch 00176: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9991 - val_loss: 1.3187 - val_acc: 0.8180
# Epoch 178/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9986Epoch 00177: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.3107 - val_acc: 0.8192
# Epoch 179/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9988Epoch 00178: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9987 - val_loss: 1.3093 - val_acc: 0.8204
# Epoch 180/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0043 - acc: 0.9988Epoch 00179: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9988 - val_loss: 1.3101 - val_acc: 0.8216
# Epoch 181/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9988Epoch 00180: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.3076 - val_acc: 0.8216
# Epoch 182/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00181: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.3115 - val_acc: 0.8192
# Epoch 183/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9992Epoch 00182: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9993 - val_loss: 1.3076 - val_acc: 0.8240
# Epoch 184/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9986Epoch 00183: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9987 - val_loss: 1.3105 - val_acc: 0.8228
# Epoch 185/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00184: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0050 - acc: 0.9988 - val_loss: 1.3176 - val_acc: 0.8216
# Epoch 186/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9986Epoch 00185: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0041 - acc: 0.9987 - val_loss: 1.3113 - val_acc: 0.8216
# Epoch 187/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0054 - acc: 0.9991Epoch 00186: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0052 - acc: 0.9991 - val_loss: 1.3210 - val_acc: 0.8204
# Epoch 188/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9989Epoch 00187: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9990 - val_loss: 1.3186 - val_acc: 0.8240
# Epoch 189/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0050 - acc: 0.9988Epoch 00188: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9988 - val_loss: 1.3159 - val_acc: 0.8251
# Epoch 190/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.9988Epoch 00189: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0045 - acc: 0.9988 - val_loss: 1.3171 - val_acc: 0.8228
# Epoch 191/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0048 - acc: 0.9991Epoch 00190: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9991 - val_loss: 1.3147 - val_acc: 0.8251
# Epoch 192/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0042 - acc: 0.9988Epoch 00191: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0042 - acc: 0.9988 - val_loss: 1.3311 - val_acc: 0.8228
# Epoch 193/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0046 - acc: 0.9986Epoch 00192: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9985 - val_loss: 1.3276 - val_acc: 0.8204
# Epoch 194/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9986Epoch 00193: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9987 - val_loss: 1.3203 - val_acc: 0.8228
# Epoch 195/200
# 6560/6680 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.9985Epoch 00194: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0043 - acc: 0.9985 - val_loss: 1.3226 - val_acc: 0.8192
# Epoch 196/200
# 6620/6680 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.9986Epoch 00195: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0051 - acc: 0.9987 - val_loss: 1.3244 - val_acc: 0.8216
# Epoch 197/200
# 6500/6680 [============================>.] - ETA: 0s - loss: 0.0035 - acc: 0.9989Epoch 00196: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.3262 - val_acc: 0.8204
# Epoch 198/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0041 - acc: 0.9985Epoch 00197: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0040 - acc: 0.9985 - val_loss: 1.3250 - val_acc: 0.8240
# Epoch 199/200
# 6660/6680 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.9989Epoch 00198: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0047 - acc: 0.9990 - val_loss: 1.3288 - val_acc: 0.8216
# Epoch 200/200
# 6640/6680 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.9989Epoch 00199: val_loss did not improve
# 6680/6680 [==============================] - 2s - loss: 0.0049 - acc: 0.9990 - val_loss: 1.3293 - val_acc: 0.8204

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
# get index of predicted dog breed for each image in test set
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 80.3828%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

from extract_bottleneck_features import *

def Resnet50_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = Resnet50_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def detector(img_path):
    
    if (face_detector(img_path)==True):
        x=Resnet50_predict_breed(img_path)
    elif (face_detector(img_path)==False):
        x=Resnet50_predict_breed(img_path)
    elif(dog_detector(img_path)==True):
        x=Resnet50_predict_breed(img_path)
    else:
        print('error')
    
    img = cv2.imread(img_path)
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # display the image, along with bounding box
    plt.imshow(cv_rgb)
    plt.show()
    
    print('You look most like a {}'.format(x))

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.


detector('ImagesforDLDogClassifier/Rottweiler.jpg')
detector('ImagesforDLDogClassifier/pitbull.jpg')
detector('ImagesforDLDogClassifier/Alejandra_Lievano.jpg')
detector('ImagesforDLDogClassifier/Carlos Lievano.jpg')
detector('ImagesforDLDogClassifier/Adrian_Lievano_Headshot_02_06_18.JPG')
detector('ImagesforDLDogClassifier/Daniel_Lievano.jpg')
detector('ImagesforDLDogClassifier/Eric_Ondarza.jpg')
detector('ImagesforDLDogClassifier/Gabriel_lievano.png')
detector('ImagesforDLDogClassifier/Olga_Lievano.jpg')
detector('ImagesforDLDogClassifier/Ozzy_headshot.jpg')

#Question 6: Output is slightly worse than I expected. 
#If I were to improve the algorithm, I'd 
#(1.) implement data augmentation, to avoid translational or rotational defects to the assignment of labels, 
#(2.) increase the number of CNN layers and MLP during the transfer learning process of our model,
#(3.) Get more data on each of the dog breeds; i think that was a major reason why the algorithm didn't perform better. We had maybe 4 images per dog breed.
# Out:
# You look most like a Beauceron
# You look most like a Bull_terrier
# You look most like a Maltese
# You look most like a Brittany
# You look most like a French_bulldog
# You look most like a Maltese
# You look most like a Poodle
# You look most like a Silky_terrier
# You look most like a English_toy_spaniel
# You look most like a Dogue_de_bordeaux
